# %% [markdown]
# # Introduction
# For those unacquainted, this is a jupyter notebook, a fairly popular and useful tool for interactive prototyping, data inspection, developing and documenting. Its content is partitioned into cells that can either contain markdown text or executable code, and further supports inline/in-cell vizualization of both plots and complex collections.
#
# The main purpose of this notebook is to provide a quick start for loading, processing and inspecting the data. Python-users  are free, and encouraged, to base their initial data exploration on this notebook, and everyone else are encouraged to take inspiration from the notebook when starting out in their language of choice. Particularly, the dataset placement and loading is important to get right in order to not check it into your own forked repositories.

# %% [markdown]
# # Data placement and loading
# We suggest that you clone/copy the dataset into your forked repositories.
# E.g., execute: <code>git clone git@github.com:sfi-norwai/2022_hackathon_hemsil2_dataset.git</code>
# when situated in the root directory of your forked repository, or use GitHub desktop etc.
#
# Ultimately, the provided *.gitignore* will ignore any directories named <code>2022_hackathon_hemsil2_dataset</code> within the repository, so as long as you name your data location accordingly, it can safely be placed within the forked repository. If you know what you are doing, you can always just keep the data outside of the repository or extend the gitignore to ignore other locations within it.

# %%
from pathlib import Path

# %% [markdown]
# ## Data path
# **Note:** Modify the raw data path if you opt for not following the suggested placement

# %%
raw_data_path = '/home/krisbrud/repos/2022_hackathon_hemsil2_dataset'
data_dir = Path(raw_data_path)
data_dir
# Out:
# PosixPath('/home/krisbrud/repos/2022_hackathon_hemsil2_dataset')

# %% [markdown]
# ## Load data
# We use the python package pandas for loading the data

# %%
import pandas as pd
import numpy as np

# %%
data_path = data_dir / "hemsil2_datapoints_20102021.csv"
meta_data_path = data_dir / "ts_info.csv"

# %% [markdown]
# ### Load data into pandas DataFrame

# %% [markdown]
# Load data points into DataFrame

# %%
data_df = pd.read_csv(data_path, sep=',', parse_dates=True, index_col=0)
data_df
# Out:
#                      flaevatn_ppt  hbv_hemsil2_inflow_pred_24h  flaevatn_temp  \
# 2010-01-01 00:00:00           0.0                     0.850000         -9.650
# 2010-01-01 01:00:00           0.0                     0.800000         -9.200
# 2010-01-01 02:00:00           0.0                     0.750000         -8.820
# 2010-01-01 03:00:00           0.0                     0.730000        -11.200
# 2010-01-01 04:00:00           0.1                     0.700000        -12.480
# ...                           ...                          ...            ...
# 2021-12-31 19:00:00           0.0                     2.767521          0.207
# 2021-12-31 20:00:00           0.0                     2.792510          0.439
# 2021-12-31 21:00:00           0.0                     2.811331         -0.030
# 2021-12-31 22:00:00           0.1                     2.775762         -0.148
# 2021-12-31 23:00:00           0.1                     2.654571         -1.241
#
#                      hbv_hemsil2_snow  hemsil2_inflow_corr  \
# 2010-01-01 00:00:00        154.410000             2.000000
# 2010-01-01 01:00:00        154.410000             2.000000
# 2010-01-01 02:00:00        154.410000             2.000000
# 2010-01-01 03:00:00        154.410000             2.000000
# 2010-01-01 04:00:00        154.560000             2.000000
# ...                               ...                  ...
# 2021-12-31 19:00:00         67.253500             3.106923
# 2021-12-31 20:00:00         67.246553             3.036134
# 2021-12-31 21:00:00         67.246553             3.060955
# 2021-12-31 22:00:00         67.384926             3.262164
# 2021-12-31 23:00:00         67.488067             3.495663
#
#                      hbv_hemsil2_ground_water  hbv_hemsil2_soil_water  \
# 2010-01-01 00:00:00                  0.730000               31.530000
# 2010-01-01 01:00:00                  0.730000               31.530000
# 2010-01-01 02:00:00                  0.730000               31.530000
# 2010-01-01 03:00:00                  0.730000               31.530000
# 2010-01-01 04:00:00                  0.730000               31.530000
# ...                                       ...                     ...
# 2021-12-31 19:00:00                  2.896317               50.454647
# 2021-12-31 20:00:00                  2.881515               50.454699
# 2021-12-31 21:00:00                  2.860236               50.454552
# 2021-12-31 22:00:00                  2.843388               50.454589
# 2021-12-31 23:00:00                  2.860065               50.455629
#
#                      hbv_hemsil2_inflow_pred_48h  hbv_hemsil2_total_water  \
# 2010-01-01 00:00:00                     0.280000                   123.03
# 2010-01-01 01:00:00                     0.280000                   123.03
# 2010-01-01 02:00:00                     0.270000                   123.03
# 2010-01-01 03:00:00                     0.270000                   123.03
# 2010-01-01 04:00:00                     0.270000                   123.12
# ...                                          ...                      ...
# 2021-12-31 19:00:00                     2.207100                      NaN
# 2021-12-31 20:00:00                     2.187476                      NaN
# 2021-12-31 21:00:00                     2.168137                      NaN
# 2021-12-31 22:00:00                     2.149075                      NaN
# 2021-12-31 23:00:00                     2.747684                      NaN
#
#                      storeskar_inflow  storeskar_temp  hbv_hemsil2_snow_cover
# 2010-01-01 00:00:00             0.520           -7.48                   100.0
# 2010-01-01 01:00:00             0.520           -7.14                   100.0
# 2010-01-01 02:00:00             0.520           -6.93                   100.0
# 2010-01-01 03:00:00             0.520           -9.87                   100.0
# 2010-01-01 04:00:00             0.520          -10.11                   100.0
# ...                               ...             ...                     ...
# 2021-12-31 19:00:00             1.193             NaN                     NaN
# 2021-12-31 20:00:00             1.193             NaN                     NaN
# 2021-12-31 21:00:00             1.193             NaN                     NaN
# 2021-12-31 22:00:00             1.193             NaN                     NaN
# 2021-12-31 23:00:00             1.193             NaN                     NaN
#
# [105192 rows x 12 columns]

# %% [markdown]
# Load column meta data into Python dictionaries that can be indexed by column names

# %%
data_df.describe()
# Out:
#         flaevatn_ppt  hbv_hemsil2_inflow_pred_24h  flaevatn_temp  \
# count  105171.000000                105134.000000  105171.000000
# mean        0.088415                    15.120137       0.899179
# std         0.391047                    20.190134       8.479834
# min         0.000000                     0.000000     -35.340000
# 25%         0.000000                     2.517110      -4.230000
# 50%         0.000000                     7.560000       1.313000
# 75%         0.000000                    20.040000       7.180000
# max        18.900000                   201.160000      24.870000
#
#        hbv_hemsil2_snow  hemsil2_inflow_corr  hbv_hemsil2_ground_water  \
# count     105171.000000        105171.000000             105180.000000
# mean          97.063158            15.914241                 24.010954
# std          105.175848            22.212225                 25.818279
# min            0.000000            -4.750000                  0.110000
# 25%            0.210000             3.090000                  1.910000
# 50%           56.814234             7.880284                 13.940000
# 75%          170.895000            19.270000                 40.220000
# max          375.090000           286.540000                113.670000
#
#        hbv_hemsil2_soil_water  hbv_hemsil2_inflow_pred_48h  \
# count           105180.000000                105108.000000
# mean                37.851188                    14.982669
# std                  4.586184                    19.736877
# min                 14.040000                     0.000000
# 25%                 36.120000                     2.290000
# 50%                 38.940000                     7.550000
# 75%                 40.720000                    20.311539
# max                 50.455629                   178.180000
#
#        hbv_hemsil2_total_water  storeskar_inflow  storeskar_temp  \
# count            104052.000000     105180.000000   102576.000000
# mean                 96.308494          4.146823        1.514413
# std                  67.899853          6.175979        9.349730
# min                   6.000000          0.110000      -38.120000
# 25%                  36.490000          0.730000       -3.530000
# 50%                  76.025000          1.780000        1.910000
# 75%                 143.320000          4.660000        8.190000
# max                 271.590000         81.910000       26.960000
#
#        hbv_hemsil2_snow_cover
# count           104124.000000
# mean                65.825800
# std                 44.198677
# min                  0.000000
# 25%                  5.960000
# 50%                100.000000
# 75%                100.000000
# max                100.000000

# %%
data_df2 = data_df[data_df.index >= pd.Timestamp(year=2018, month=1, day=1)]
cols_to_plot = [
    # "hemsil2_inflow_corr",
    "flaevatn_ppt",
]

data_df2.plot(y="hemsil2_inflow_corr")
data_df2.plot(y=cols_to_plot)
# Out:
# <AxesSubplot:>

# %%
meta_data_df = pd.read_csv(meta_data_path, sep=',', index_col=0)
meta_data_dict = {record['name']: record for record in meta_data_df.to_dict('records')}
meta_data_dict
# Out:
# {'flaevatn_ppt': {'id': 224500448798060,
#   'externalId': 'flaevatn_ppt',
#   'name': 'flaevatn_ppt',
#   'isString': False,
#   'metadata': "{'prediction': 'false'}",
#   'unit': 'mm',
#   'assetId': 1473462549666207,
#   'isStep': False,
#   'securityCategories': '[]',
#   'dataSetId': 1349361264490416,
#   'createdTime': 1633594289762,
#   'lastUpdatedTime': 1655361576439},
#  'hbv_hemsil2_inflow_pred_24h': {'id': 3221784815662866,
#   'externalId': 'hbv_hemsil2_inflow_pred_24h',
#   'name': 'hbv_hemsil2_inflow_pred_24h',
#   'isString': False,
#   'metadata': "{'prediction': 'true', 'horizon': '24h'}",
#   'unit': 'Q/h',
#   'assetId': 1473462549666207,
#   'isStep': False,
#   'securityCategories': '[]',
#   'dataSetId': 1349361264490416,
#   'createdTime': 1635256682345,
#   'lastUpdatedTime': 1655361577122},
#  'flaevatn_temp': {'id': 3292601046790046,
#   'externalId': 'flaevatn_temp',
#   'name': 'flaevatn_temp',
#   'isString': False,
#   'metadata': "{'prediction': 'false'}",
#   'unit': 'C',
#   'assetId': 1473462549666207,
#   'isStep': False,
#   'securityCategories': '[]',
#   'dataSetId': 1349361264490416,
#   'createdTime': 1633594289872,
#   'lastUpdatedTime': 1655361577332},
#  'hbv_hemsil2_snow': {'id': 4115876320431373,
#   'externalId': 'hbv_hemsil2_snow',
#   'name': 'hbv_hemsil2_snow',
#   'isString': False,
#   'metadata': "{'prediction': 'false'}",
#   'unit': 'mm',
#   'assetId': 1473462549666207,
#   'isStep': False,
#   'securityCategories': '[]',
#   'dataSetId': 1349361264490416,
#   'createdTime': 1633594290012,
#   'lastUpdatedTime': 1655361577753},
#  'hemsil2_inflow_corr': {'id': 4584414310641717,
#   'externalId': 'hemsil2_inflow_corr',
#   'name': 'hemsil2_inflow_corr',
#   'isString': False,
#   'metadata': "{'prediction': 'false'}",
#   'unit': 'Q/s',
#   'assetId': 1473462549666207,
#   'isStep': False,
#   'securityCategories': '[]',
#   'dataSetId': 1349361264490416,
#   'createdTime': 1633594290171,
#   'lastUpdatedTime': 1655361578086},
#  'hbv_hemsil2_ground_water': {'id': 5073395944557095,
#   'externalId': 'hbv_hemsil2_ground_water',
#   'name': 'hbv_hemsil2_ground_water',
#   'isString': False,
#   'metadata': "{'prediction': 'false'}",
#   'unit': 'mm',
#   'assetId': 1473462549666207,
#   'isStep': False,
#   'securityCategories': '[]',
#   'dataSetId': 1349361264490416,
#   'createdTime': 1637235105029,
#   'lastUpdatedTime': 1655361578407},
#  'hbv_hemsil2_soil_water': {'id': 5441222589206595,
#   'externalId': 'hbv_hemsil2_soil_water',
#   'name': 'hbv_hemsil2_soil_water',
#   'isString': False,
#   'metadata': "{'prediction': 'false'}",
#   'unit': 'mm',
#   'assetId': 1473462549666207,
#   'isStep': False,
#   'securityCategories': '[]',
#   'dataSetId': 1349361264490416,
#   'createdTime': 1637235105272,
#   'lastUpdatedTime': 1655361578511},
#  'hbv_hemsil2_inflow_pred_48h': {'id': 5681902222144763,
#   'externalId': 'hbv_hemsil2_inflow_pred_48h',
#   'name': 'hbv_hemsil2_inflow_pred_48h',
#   'isString': False,
#   'metadata': "{'prediction': 'true', 'horizon': '48h'}",
#   'unit': 'm3/s',
#   'assetId': 1473462549666207,
#   'isStep': False,
#   'securityCategories': '[]',
#   'dataSetId': 1349361264490416,
#   'createdTime': 1637074841560,
#   'lastUpdatedTime': 1655361578626},
#  'hbv_hemsil2_total_water': {'id': 6344721276076312,
#   'externalId': 'hbv_hemsil2_total_water',
#   'name': 'hbv_hemsil2_total_water',
#   'isString': False,
#   'metadata': "{'prediction': 'false'}",
#   'unit': 'Mm3',
#   'assetId': 1473462549666207,
#   'isStep': False,
#   'securityCategories': '[]',
#   'dataSetId': 1349361264490416,
#   'createdTime': 1637660101615,
#   'lastUpdatedTime': 1655361579059},
#  'storeskar_inflow': {'id': 6791408947225135,
#   'externalId': 'storeskar_inflow',
#   'name': 'storeskar_inflow',
#   'isString': False,
#   'metadata': "{'prediction': 'false'}",
#   'unit': 'Q/h',
#   'assetId': 1473462549666207,
#   'isStep': False,
#   'securityCategories': '[]',
#   'dataSetId': 1349361264490416,
#   'createdTime': 1635249759064,
#   'lastUpdatedTime': 1655361579164},
#  'storeskar_temp': {'id': 7097540881814223,
#   'externalId': 'storeskar_temp',
#   'name': 'storeskar_temp',
#   'isString': False,
#   'metadata': "{'prediction': 'false'}",
#   'unit': 'C',
#   'assetId': 1473462549666207,
#   'isStep': False,
#   'securityCategories': '[]',
#   'dataSetId': 1349361264490416,
#   'createdTime': 1633594289939,
#   'lastUpdatedTime': 1655361579289},
#  'hbv_hemsil2_snow_cover': {'id': 7534051250479481,
#   'externalId': 'hbv_hemsil2_snow_cover',
#   'name': 'hbv_hemsil2_snow_cover',
#   'isString': False,
#   'metadata': "{'prediction': 'false'}",
#   'unit': '%',
#   'assetId': 1473462549666207,
#   'isStep': False,
#   'securityCategories': '[]',
#   'dataSetId': 1349361264490416,
#   'createdTime': 1637235105149,
#   'lastUpdatedTime': 1655361579706}}

# %% [markdown]
# ## Identify missing data
# Loading the data points into a pandas DataFrame seems to have worked fine, but closer inspection reveals that all columns contain "null-values"

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 105192 entries, 2010-01-01 00:00:00 to 2021-12-31 23:00:00
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   flaevatn_ppt                 105171 non-null  float64
#  1   hbv_hemsil2_inflow_pred_24h  105134 non-null  float64
#  2   flaevatn_temp                105171 non-null  float64
#  3   hbv_hemsil2_snow             105171 non-null  float64
#  4   hemsil2_inflow_corr          105171 non-null  float64
#  5   hbv_hemsil2_ground_water     105180 non-null  float64
#  6   hbv_hemsil2_soil_water       105180 non-null  float64
#  7   hbv_hemsil2_inflow_pred_48h  105108 non-null  float64
#  8   hbv_hemsil2_total_water      104052 non-null  float64
#  9   storeskar_inflow             105180 non-null  float64
#  10  storeskar_temp               102576 non-null  float64
#  11  hbv_hemsil2_snow_cover       104124 non-null  float64
# dtypes: float64(12)
# memory usage: 10.4 MB

# %% [markdown]
# If we zoom in on some columns, we can notice some patterns in the missing data. E.g., flaevath_ppt, flaevatn_temp and other columns with 105171 non-null values are all NaN in most rows of the date 2021-09-14, while many of the remaining columns are consistenly NaN for the "skipped" hour when switching to daylight saving, e.g., storeskar_inflow. A few columns have a lot of missing values in the last months of the dataset

# %%
# Simple help function for extracting all rows where a given column has NaN values
def extract_null_df(df, column):
    return df[df[column].isnull()]

# %%
# Rerun cell with different column names to inspect rows where said column is null
column_name = 'storeskar_inflow'
null_rows = extract_null_df(data_df, column_name)
null_rows

# %% [markdown]
# ## Handling missing data
# In real-world data, you have to expect some missing data. These may be caused by a myriad of issues like downtimes of sensors, communication and databases etc. There are multiple ways of handling such issues, each with their own sets of pros and cons.
#
# We provide an optional process for filling in all missing data points below

# %% [markdown]
# ### [OPTIONAL] Simple removal of missing data
# Given the observations above, a simple idea is to simply drop all data after a cut-off point beginning with the problematic date 2021-09-14, as this only makes out a couple of months out of 12 years of data. The remaining NaNs are exclusively caused by the switch to daylight saving and the entire timestamp does not really exist within the timezone. As long as the dataset does not provide absolute timestamps, the simplest course of action is likely to just fill in the NaNs using linear interpolation or back/front fill. **Note:** That the raw data likely has overwritten datapoints when switching from daylight saving in the autumn as well. All in all, these two abnormalities should not affect any models too much, and if you do not want to spend time on more advanced processing, it should be safe to use this.

# %% [markdown]
# Drop all data after 2021-09-13

# %%
data_df = data_df[data_df.index < pd.Timestamp(year=2021, month=9, day=1)]

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 102264 entries, 2010-01-01 00:00:00 to 2021-08-31 23:00:00
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   flaevatn_ppt                 102264 non-null  float64
#  1   hbv_hemsil2_inflow_pred_24h  102254 non-null  float64
#  2   flaevatn_temp                102264 non-null  float64
#  3   hbv_hemsil2_snow             102264 non-null  float64
#  4   hemsil2_inflow_corr          102264 non-null  float64
#  5   hbv_hemsil2_ground_water     102252 non-null  float64
#  6   hbv_hemsil2_soil_water       102252 non-null  float64
#  7   hbv_hemsil2_inflow_pred_48h  102252 non-null  float64
#  8   hbv_hemsil2_total_water      102252 non-null  float64
#  9   storeskar_inflow             102253 non-null  float64
#  10  storeskar_temp               102264 non-null  float64
#  11  hbv_hemsil2_snow_cover       102252 non-null  float64
# dtypes: float64(12)
# memory usage: 10.1 MB

# %%
data_df.plot("")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/norwai/lib/python3.10/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/anaconda3/envs/norwai/lib/python3.10/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/envs/norwai/lib/python3.10/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_45110/2576344598.py in <module>
# ----> 1 data_df.plot("")
#
# ~/anaconda3/envs/norwai/lib/python3.10/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     935                 if is_integer(x) and not data.columns.holds_integer():
#     936                     x = data_cols[x]
# --> 937                 elif not isinstance(data[x], ABCSeries):
#     938                     raise ValueError("x must be a label or position")
#     939                 data = data.set_index(x)
#
# ~/anaconda3/envs/norwai/lib/python3.10/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~/anaconda3/envs/norwai/lib/python3.10/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: ''

# %% [markdown]
# Fill NaNs caused by switching to daylight saving using linear interpolation

# %%
data_df = data_df.interpolate(method='linear')

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 102264 entries, 2010-01-01 00:00:00 to 2021-08-31 23:00:00
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   flaevatn_ppt                 102264 non-null  float64
#  1   hbv_hemsil2_inflow_pred_24h  102264 non-null  float64
#  2   flaevatn_temp                102264 non-null  float64
#  3   hbv_hemsil2_snow             102264 non-null  float64
#  4   hemsil2_inflow_corr          102264 non-null  float64
#  5   hbv_hemsil2_ground_water     102264 non-null  float64
#  6   hbv_hemsil2_soil_water       102264 non-null  float64
#  7   hbv_hemsil2_inflow_pred_48h  102264 non-null  float64
#  8   hbv_hemsil2_total_water      102264 non-null  float64
#  9   storeskar_inflow             102264 non-null  float64
#  10  storeskar_temp               102264 non-null  float64
#  11  hbv_hemsil2_snow_cover       102264 non-null  float64
# dtypes: float64(12)
# memory usage: 10.1 MB

# %% [markdown]
# **Note:** A more intricate processing where only larger chunks of missing data are removed, while keeping track of the valid intervals is likely better. It would probably also be better to convert all times to UTC to avoid daylight saving issues, but you will then have to handle the overwritted hour in the autumn (interpolation etc)

# %% [markdown]
# # Preprocessing

# %%
import sklearn

# %%
# data_df[data_df.index >= "2020-01-01"]

data_df.index >= "2020-01-01"
data_df.index <= "2021-01-01"

is_2020 = (data_df.index >= "2020-01-01") & (data_df.index < "2021-01-01")
data_df[is_2020]
# Out:
#                      flaevatn_ppt  hbv_hemsil2_inflow_pred_24h  flaevatn_temp  \
# 2020-01-01 00:00:00           0.0                         5.92           0.45
# 2020-01-01 01:00:00           0.0                         5.86           0.44
# 2020-01-01 02:00:00           0.0                         5.78           0.13
# 2020-01-01 03:00:00           0.0                         5.67          -0.30
# 2020-01-01 04:00:00           0.0                         5.55          -0.34
# ...                           ...                          ...            ...
# 2020-12-31 19:00:00           0.3                         1.53          -6.09
# 2020-12-31 20:00:00           0.4                         1.47          -6.15
# 2020-12-31 21:00:00           0.2                         1.42          -6.28
# 2020-12-31 22:00:00           0.1                         1.38          -6.71
# 2020-12-31 23:00:00           0.1                         1.34          -8.19
#
#                      hbv_hemsil2_snow  hemsil2_inflow_corr  \
# 2020-01-01 00:00:00            177.25                 6.03
# 2020-01-01 01:00:00            177.19                 5.33
# 2020-01-01 02:00:00            177.13                 4.94
# 2020-01-01 03:00:00            177.07                 5.10
# 2020-01-01 04:00:00            177.02                 5.65
# ...                               ...                  ...
# 2020-12-31 19:00:00            166.22                 5.00
# 2020-12-31 20:00:00            166.78                 4.76
# 2020-12-31 21:00:00            167.07                 4.59
# 2020-12-31 22:00:00            167.21                 4.50
# 2020-12-31 23:00:00            167.35                 4.44
#
#                      hbv_hemsil2_ground_water  hbv_hemsil2_soil_water  \
# 2020-01-01 00:00:00                      1.89                   38.09
# 2020-01-01 01:00:00                      1.88                   38.09
# 2020-01-01 02:00:00                      1.88                   38.09
# 2020-01-01 03:00:00                      1.87                   38.09
# 2020-01-01 04:00:00                      1.87                   38.09
# ...                                       ...                     ...
# 2020-12-31 19:00:00                      3.77                   41.59
# 2020-12-31 20:00:00                      3.78                   41.59
# 2020-12-31 21:00:00                      3.78                   41.59
# 2020-12-31 22:00:00                      3.77                   41.59
# 2020-12-31 23:00:00                      3.77                   41.59
#
#                      hbv_hemsil2_inflow_pred_48h  hbv_hemsil2_total_water  \
# 2020-01-01 00:00:00                         4.03                   139.68
# 2020-01-01 01:00:00                         3.97                   139.67
# 2020-01-01 02:00:00                         3.93                   139.66
# 2020-01-01 03:00:00                         3.88                   139.64
# 2020-01-01 04:00:00                         3.83                   139.63
# ...                                          ...                      ...
# 2020-12-31 19:00:00                         1.00                   134.96
# 2020-12-31 20:00:00                         0.98                   135.32
# 2020-12-31 21:00:00                         0.96                   135.49
# 2020-12-31 22:00:00                         0.94                   135.58
# 2020-12-31 23:00:00                         0.93                   135.66
#
#                      storeskar_inflow  storeskar_temp  hbv_hemsil2_snow_cover
# 2020-01-01 00:00:00              1.60            1.46                   100.0
# 2020-01-01 01:00:00              1.58            2.03                   100.0
# 2020-01-01 02:00:00              1.59            1.75                   100.0
# 2020-01-01 03:00:00              1.63            1.88                   100.0
# 2020-01-01 04:00:00              1.71            1.79                   100.0
# ...                               ...             ...                     ...
# 2020-12-31 19:00:00              1.97           -6.03                   100.0
# 2020-12-31 20:00:00              1.97           -5.61                   100.0
# 2020-12-31 21:00:00              1.97           -6.62                   100.0
# 2020-12-31 22:00:00              1.96           -8.13                   100.0
# 2020-12-31 23:00:00              1.95           -7.26                   100.0
#
# [8782 rows x 12 columns]

# %%
# TODO: Train/test-split
# TODO: Let 2020 be test year
# make x_train, y_train, x_test, y_test

#dropping missing values
data_df = data_df.dropna(axis=0)

#selecting the prediction variable 
y = data_df.hemsil2_inflow_corr

#chosing features
data_features = ['flaevatn_ppt', 'flaevatn_temp', 'hbv_hemsil2_snow', 'hbv_hemsil2_ground_water', 'hbv_hemsil2_soil_water', 'hbv_hemsil2_total_water', 'storeskar_temp', 'hbv_hemsil2_snow_cover', 'hbv_hemsil2_inflow_pred_24h', 'hbv_hemsil2_inflow_pred_48h']

X = data_df[data_features]

test_year = 2010
hemsil2_inflo_corr_prediction[]

for(int = test_yea)
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# ~/anaconda3/envs/norwai/lib/python3.10/site-packages/pandas/_libs/tslibs/timedeltas.pyx in pandas._libs.tslibs.timedeltas.delta_to_nanoseconds()
#
# OverflowError: Python int too large to convert to C long
#
# The above exception was the direct cause of the following exception:
#
# OutOfBoundsTimedelta                      Traceback (most recent call last)
# /tmp/ipykernel_45110/3902548901.py in <module>
#      14 X = data_df[data_features]
#      15
# ---> 16 X.index = pd.date_range('1/1/2010 01:00:00', periods=102241, freq='W')
#      17
#      18
#
# ~/anaconda3/envs/norwai/lib/python3.10/site-packages/pandas/core/indexes/datetimes.py in date_range(start, end, periods, freq, tz, normalize, name, closed, inclusive, **kwargs)
#    1085         freq = "D"
#    1086
# -> 1087     dtarr = DatetimeArray._generate_range(
#    1088         start=start,
#    1089         end=end,
#
# ~/anaconda3/envs/norwai/lib/python3.10/site-packages/pandas/core/arrays/datetimes.py in _generate_range(cls, start, end, periods, freq, tz, normalize, ambiguous, nonexistent, inclusive)
#     446             else:
#     447                 xdr = generate_range(start=start, end=end, periods=periods, offset=freq)
# --> 448                 values = np.array([x.value for x in xdr], dtype=np.int64)
#     449
#     450             _tz = start.tz if start is not None else end.tz
#
# ~/anaconda3/envs/norwai/lib/python3.10/site-packages/pandas/core/arrays/datetimes.py in <listcomp>(.0)
#     446             else:
#     447                 xdr = generate_range(start=start, end=end, periods=periods, offset=freq)
# --> 448                 values = np.array([x.value for x in xdr], dtype=np.int64)
#     449
#     450             _tz = start.tz if start is not None else end.tz
#
# ~/anaconda3/envs/norwai/lib/python3.10/site-packages/pandas/core/arrays/datetimes.py in generate_range(start, end, periods, offset)
#    2586
#    2587     if end is None:
# -> 2588         end = start + (periods - 1) * offset
#    2589
#    2590     if start is None:
#
# ~/anaconda3/envs/norwai/lib/python3.10/site-packages/pandas/_libs/tslibs/offsets.pyx in pandas._libs.tslibs.offsets.BaseOffset.__add__()
#
# ~/anaconda3/envs/norwai/lib/python3.10/site-packages/pandas/_libs/tslibs/offsets.pyx in pandas._libs.tslibs.offsets.BaseOffset.__add__()
#
# ~/anaconda3/envs/norwai/lib/python3.10/site-packages/pandas/_libs/tslibs/offsets.pyx in pandas._libs.tslibs.offsets.apply_wraps.wrapper()
#
# ~/anaconda3/envs/norwai/lib/python3.10/site-packages/pandas/_libs/tslibs/offsets.pyx in pandas._libs.tslibs.offsets.Week._apply()
#
# ~/anaconda3/envs/norwai/lib/python3.10/site-packages/pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# ~/anaconda3/envs/norwai/lib/python3.10/site-packages/pandas/_libs/tslibs/timedeltas.pyx in pandas._libs.tslibs.timedeltas.delta_to_nanoseconds()
#
# OutOfBoundsTimedelta: Python int too large to convert to C long

# %%
# TODO: Normalization

# %%
# TODO (After a while): Make features for seasonal variance

# %% [markdown]
# # Model training

# %%
# TODO: Linear regression
# Code mostly based on examples from sklearn documentation as of now

import sklearn
from sklearn import linear_model
linreg = linear_model.LinearRegression()
# linreg.fit(x=x_train, y=y_train)
# y_pred_linreg = linreg.predict(x_test)

ridge_reg = linear_model.Ridge(alpha=.5)
ridge_reg.fit(x=x_train, y=y_train)
y_pred_linreg = ridge_reg.predict(x_test)

lasso_reg = linear_model.Lasso(alpha=0.1)
lasso_reg.fit(x=x_train, y=y_train)
y_pred_linreg = lasso_reg.predict(x_test)

# %%
# TODO: PCR (Principal Component Regression)
# Based on https://scikit-learn.org/stable/auto_examples/cross_decomposition/plot_pcr_vs_pls.html
from sklearn.pipeline import make_pipeline
from sklearn.decomposition import PCA

pcr_reg = make_pipeline(PCA(n_components=2), linear_model.LinearRegression())
pcr_reg.fit(x=x_train, y=y_train)
y_pred_pcr = pcr_reg.predict(x_test)
# Out:
#   File "/tmp/ipykernel_45110/885964430.py", line 2
#     pcr_reg = .Lasso(alpha=0.1)
#               ^
# SyntaxError: invalid syntax

# %%
# TODO: kNN-regression
from sklearn import neighbors
n_neighbors = 7
knn_reg = neighbors.KNeighborsRegressor(n_neighbors, 
    weights="uniform",
    # weights="distace",
)
knn_reg.fit(x=x_train, y=y_train)

# %%
# TODO: Gradient boosting (xgboost etc.)
from sklearn.ensemble import RandomForestRegressor
random_forest_reg = RandomForestRegressor(n_estimators=10)
random_forest_reg.fit(x=x_train, y=y_train)
y_pred_rf = random_forest_reg.predict(x_test)

# %% [markdown]
# # Evaluation

# %%
# TODO: MSE (Mean Square Error) and MAE (Mean Absolute Error)
